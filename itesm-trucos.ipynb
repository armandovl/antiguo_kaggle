# %%
import numpy as np

# %%
a= np.array([0,1,2,0,2,2,1])
print(a==0)

# %%
a0=1*(a==0)
a1=1*(a==1)
print(a1)

# %%
b=np.array([0.91,0.54,0.02])
res= np.argmax(b)
print(res)

# %%
#premio turing 2011 la invesión de las redes bayes la única aportación de la computación a las matemáticas
