# %%
Datos1<-read.csv("../input/arbol_covid.csv") #traemos el dataframe
head(Datos1,10) #primeros 10 registros
str(Datos1) #estructura de los datos


library(party)
modelo_party<-ctree(ESTIMADOS_SINTOMAS~.,Datos1)
plot(modelo_party)
